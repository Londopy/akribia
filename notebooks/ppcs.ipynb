# %% [markdown]
# # PPCS — sensorimotor forward-model mismatch
#
# The most mathematically distinct module: a state-space forward model of self-motion. `ppcs_forward_model` impairs the update rate so the mismatch persists. See `docs/THEORY.md` §4.

# %% [markdown]
# ## Vestibular mismatch — PPCS fails to habituate

# %%
from akribia import profiles
from akribia.tasks import self_motion_task as m
for p in ['baseline','ppcs_forward_model']:
    s = m.run(profiles.get(p))['summary']
    print(f"{p:18s} recovery_steps={s['recovery_steps_mean']:.1f} residual={s['residual_mismatch']:.3f}")
