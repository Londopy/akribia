# %% [markdown]
# # ADHD — reward-prediction-error and temporal discounting
#
# ADHD modelled as a reward/valuation problem (not perceptual): steep discounting (`adhd_discounting`) or unstable reward gain (`adhd_rpe_noise`). See `docs/THEORY.md` §3.

# %% [markdown]
# ## Delay discounting — steeper γ collapses the AUC impulsivity measure

# %%
from akribia import profiles
from akribia.tasks import delay_discounting_task as d
for p in ['baseline','adhd_discounting']:
    s = d.run(profiles.get(p))['summary']
    print(f"{p:16s} AUC={s['auc_impulsivity']:.3f}")
